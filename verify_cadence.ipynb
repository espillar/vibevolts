# %%
from importlib import reload
import verify_cadence

# %%
reload(verify_cadence)
verify_cadence.run_verification()
# Out:
# --- Starting Cadence Controller Verification ---
# Added 23 satellites.
# Generating pointing sphere with 100 points...
# Cadence initialized.
# Group 0: Interval=10.0s, Count=11
# Group 1: Interval=30.0s, Count=12
#
# --- Plotting Initial Positions ---
# --- Running Iterations ---
#
# Step 1:
#   Scheduled: Time=2024-01-01 12:00:00+00:00, Group=0
# Using filter: V
# sun, space, sky
#     4.529e+20, 2.360e+11, 6.499e+11
# Sat 0 (itime=10.0s) detects Target 0:
#   Signal:    1.043e+05 | Noise:    1.998e+01 | SNR:    5.220e+03
# Sat 0 (itime=10.0s) detects Target 1:
#   Signal:    3.299e+04 | Noise:    1.998e+01 | SNR:    1.651e+03
# Sat 0 (itime=10.0s) detects Target 2:
#   Signal:    1.801e+03 | Noise:    1.998e+01 | SNR:    9.015e+01
# Sat 0 (itime=10.0s) detects Target 3:
#   Signal:    4.435e+03 | Noise:    1.998e+01 | SNR:    2.219e+02
# Sat 0 (itime=10.0s) detects Target 4:
#   Signal:    1.650e+03 | Noise:    1.998e+01 | SNR:    8.256e+01
# ...
