# %%
from importlib import reload
from constants import ARCSEC

# %%
from radiometry_calcs import fluxes

# %%
fluxes('V')
# Out:
# (4.528859785873655e+20, 235960409623.85077, 649888933037.443)

# %%
sun, space, sky = fluxes('V')

# %%
print(space/sky)
# Out:
# 0.3630780547701003

# %%
print(sky * ARCSEC * ARCSEC)
# Out:
# 15.275269284707015
