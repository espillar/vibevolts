# %%
from importlib import reload

# %%
import detector
from constants import *
reload(detector)
# Out:
# <module 'detector' from '/Users/espillar/Desktop/vibevolts/detector.py'>

# %%
reload(detector)
filt, detect = detector.makeDetector(1, "V", 1, 1* ARCSEC, 1)
print(filt)
print(detect)
print(detector.requiredIntegrationTime(20, filt,detect))
# Out:
# ['V']
# [[1.0000000e+00 4.8480000e-06 5.0000000e-01 7.0000000e-01 2.3503104e-11
#   3.4900000e-01 1.7450000e-01 2.6175000e-01 2.3000000e+01 8.7900000e+09
#   0.0000000e+00]]
# [659.24312041]

# %%
from importlib import reload

# %%
import demo_requiredIntegrationTime
reload( demo_requiredIntegrationTime)
fig = demo_requiredIntegrationTime.demo_requiredIntegrationTime()
fig.show()
# Out:
# [[1.00000000e+00 4.84800000e-06 1.00000000e+00 1.00000000e+00
#   8.57613977e-11 3.49000000e-01 1.74500000e-01 2.61750000e-01
#   2.30000000e+01 8.79000000e+09 0.00000000e+00]]
# Detector Specifications:
#   Aperture: 1.0 m
#   Pixel Size: 4.848e-06 rad
#   QE: 1.0
#   Photometric Efficiency: 1.0
#   Pixels: 8.576139768967416e-11
#   Solar Exclusion: 0.349 rad
#   Lunar Exclusion: 0.1745 rad
#   Earth Exclusion: 0.26175 rad
#   Sky Background: 23.0
#   Filter Band Cal: V

# %%
from constants import *
import detector
reload(detector)
# Out:
# <module 'detector' from '/Users/espillar0/Desktop/vibevolts/detector.py'>

# %%
detector.testdetector()
# Out:
# [202858.84606778]

# %%
from importlib import reload

# %%
filt, detect = detector.makeDetector(1, "V", 1 * DEGREE,
                              1 * ARCSEC, 1, 
                              qe = 0.2, photfrac = 1.0)

# %%
print(detect)
# Out:
# [[1.00000000e+00 4.84813681e-06 2.00000000e-01 1.00000000e+00
#   7.71604938e-08 3.49065850e-01 1.74532925e-01 2.61799388e-01
#   2.30000000e+01 8.79000000e+09 0.00000000e+00]]
