# %% [markdown]
# # Initialize sim_data

# %%
from importlib import reload

# %%
from demo_common import initialize_standard_simulation

# %%
sim_data = initialize_standard_simulation()
# Out:
# Initializing standard simulation with 23 satellites.
# Propagating satellites to start time: 2025-12-31T16:28:49.022358+00:00 to set initial state.

# %%
sim_data.keys()
# Out:
# dict_keys(['start_time', 'time', 'delta_time', 'counts', 'pointing_spheres', 'detector', 'satellites', 'observatories', 'celestial', 'fixedpoints'])

# %%
import celestialbodies
x= celestialbodies.celestial_update(sim_data)

# %%
sim_data['satellites'].keys()
# Out:
# dict_keys(['position', 'velocity', 'acceleration', 'orbital_elements', 'epochs', 'pointing', 'pointing_state'])

# %%
sim_data['celestial']['position'][0]
# Out:
# array([ 2.52527489e+10, -1.32965725e+11, -5.76379933e+10])

# %%
satpositions = sim_data['satellites']['position'] # all satellite positions

# %%
len(satpositions)
# Out:
# 23

# %% [markdown]
# # Start testing scandetectors

# %%
import scandetectors
import inspect

# %%
import scandetectors

# %%
scandetectors.scandetectors(sim_data)
# Out:
# scansensors function called with simulation data.
# (23, 3)  sat positions
# (100, 3)  tagets
# (3,)  satposition
# (100, 3)  toTargests
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 scandetectors.scandetectors(sim_data)
#
# File ~/Desktop/vibevolts/scandetectors.py:44, in scandetectors(sim_data)
#      42          toTargets = targets - satposition
#      43          print(toTargets.shape,' toTargests')
# ---> 44          print(detectorVect.shape, ' detectorVect')
#      45 #     Assuming V and W are (n, 3) arrays
#      46 #         dot_products = np.einsum('ij,ij->i', toTargets, detectorVect)
#      47 #         print(dot_products)
#    (...)     78     # # This handles the "wrap-around" at the 180-degree boundary
#      79     # delta_phi = (delta_phi + np.pi) % (2 * np.pi) - np.pi
#      81     return(0)
#
# AttributeError: 'types.SimpleNamespace' object has no attribute 'shape'

# %%
sim_data.keys()
# Out:
# dict_keys(['start_time', 'time', 'delta_time', 'counts', 'pointing_spheres', 'detector', 'satellites', 'observatories', 'celestial', 'fixedpoints'])

# %%
sim_data['satellites'].keys()
# Out:
# dict_keys(['position', 'velocity', 'acceleration', 'orbital_elements', 'epochs', 'pointing', 'pointing_state'])

# %%
sim_data['satellites']['pointing']
# Out:
# array([[ 2.91073090e-01,  9.55751572e-01,  4.26073813e-02],
#        [-4.33883870e-01, -9.00951926e-01,  5.51484259e-03],
#        [ 2.77263820e-01, -8.47105771e-01,  4.53361431e-01],
#        [-7.99782751e-01, -6.00289327e-01, -5.23851394e-04],
#        [-2.94196624e-01, -9.55744773e-01, -5.23851394e-04],
#        [ 8.97921022e-01, -4.40155758e-01, -8.63928817e-04],
#        [ 5.75171265e-01,  8.18032719e-01, -6.97962922e-04],
#        [-7.18076557e-01,  6.95964111e-01, -1.23021294e-04],
#        [-7.99638566e-01, -6.00481381e-01,  5.24018993e-04],
#        [ 4.68066288e-01, -8.83692935e-01,  8.63977524e-04],
#        [ 9.46047293e-01,  3.24027827e-01,  6.97795324e-04],
#        [-1.71914236e-01,  9.85111913e-01,  1.22972587e-04],
#        [-9.99879051e-01, -1.55437607e-02, -5.23851394e-04],
#        [-2.44273385e-01,  3.97831513e-01,  8.84341902e-01],
#        [-4.12242336e-01, -1.76139803e-01,  8.93885354e-01],
#        [ 1.21341481e-01, -4.66823985e-01,  8.75986080e-01],
#        [ 5.77686824e-01,  5.39456805e-02,  8.14473938e-01],
#        [ 2.93271405e-02,  7.98933758e-01,  6.00703561e-01],
#        [ 4.84793466e-01, -6.87835936e-01,  5.40237930e-01],
#        [ 4.59885733e-01,  8.59379557e-01,  2.23543932e-01],
#        [-7.17688480e-01, -1.19551059e-01,  6.86025356e-01],
#        [ 7.26418810e-01, -3.59150416e-01,  5.85940861e-01],
#        [ 9.31213305e-01, -2.77568100e-01, -2.36215434e-01]])

# %%
len(sim_data['detector']aperture'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 len(sim_data['detector']['aperture'])
#
# TypeError: 'types.SimpleNamespace' object is not subscriptable

# %%
dir(sim_data['detector'])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'aperture',
#  'earthEx',
#  'filt',
#  'fov',
#  'ifov',
#  'itime',
#  'lunarex',
#  'photoEff',
#  'pixCount',
#  'pixelArea',
#  'qe',
#  'skyBack',
#  'solarEx',
#  'zpCal']

# %%
len(sim_data['detector'].filt)
# Out:
# 23
