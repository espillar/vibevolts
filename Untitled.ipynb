# %%
filter = "B"
print([filter] * 3)
# Out:
# ['B', 'B', 'B']

# %%
from importlib import reload

# %%
import constants
import constellation

# %% [raw]
# from constants import *

# %%
reload(constants)
reload(all_demos)
reload(constellation)
# Out:
# <module 'constellation' from '/Users/espillar/Desktop/vibevolts/constellation.py'>

# %%
import all_demos

# %%
all_demos.run_all_demos()
# Out:
# --- Running All Demos ---
#
# --- Executing demo_constellation ---
# Initializing standard simulation with 23 satellites.
# Propagating satellites to start time: 2025-07-27T22:27:00+00:00 to set initial state.
# Generating pointing sphere with 2000 points...
# appending a single item
#
# --- Executing show_geo_search ---
# Generating pointing sphere with 125 points...
# I have a tuple
# extracting an item from a tuple
# extracting an item from a tuple
# extracting an item from a tuple
# extracting an item from a tuple
#
# --- Executing demo_requiredIntegrationTime ---
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 all_demos.run_all_demos()
#
# File ~/Desktop/vibevolts/all_demos.py:51, in run_all_demos(save_html)
#      49 for func in demo_functions:
#      50     print(f"\n\033--- Executing {func.__name__} ---\033")
# ---> 51     res = func()
# ...

# %%
# %run plot_satellite_brighness.py

# %%
reload(constellation)
# Out:
# <module 'constellation' from '/Users/espillar/Desktop/vibevolts/constellation.py'>

# %%
from importlib import reload
import constellation
import constants

# %%
reload(constants)
reload(constellation)
print(constants.DETECTOR_LUNAR_EXCL_IDX)
print(constellation.makeDetector(1, "V", 1,1,1,20))
# Out:
# 6
# (1, 11)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 4
#       2 reload(constellation)
#       3 print(constants.DETECTOR_LUNAR_EXCL_IDX)
# ----> 4 print(constellation.makeDetector(1, "V", 1,1,1,20))
#
# File ~/Desktop/vibevolts/constellation.py:112, in makeDetector(n, band, fov, ifov, aper, limitingmag, qe, photfrac, solarex, lunarex, earthex)
#     110 detect[:,DETECTOR_EARTH_EXCL_IDX] = earthex  # eearth exclusion angle
#     111 detect[:,DETECTOR_SKY_BACK_IDX] = FILTER_DATA[band]['space'] # photon backgroud
# --> 112 detect[:,DETECTOR_FILTER_BAND_IDX] = band # Band
#     113 detect[:,DETECTOR_FILTER_BAND_CAL_IDX] = FILTER_DATA[band]['zero_point'] # Filter Zero Point
#     114 return(detect)
#
# ValueError: could not convert string to float: 'V'

# %%
# ?detect
# Out:
# Object `detect` not found.

# %%
from radiometry_data import FILTER_DATA

# %%
print(FILTER_DATA)
# Out:
# {'U': {'sun': -26.03, 'sky': 22.0, 'space': 22.9, 'central_wavelength': 365.0, 'bandwidth': 66.0, 'zero_point': 4960000000.0}, 'B': {'sun': -26.13, 'sky': 22.7, 'space': 23.3, 'central_wavelength': 445.0, 'bandwidth': 94.0, 'zero_point': 13600000000.0}, 'V': {'sun': -26.78, 'sky': 21.9, 'space': 23, 'central_wavelength': 551.0, 'bandwidth': 88.0, 'zero_point': 8790000000.0}, 'R': {'sun': -27.11, 'sky': 21.0, 'space': 22.0, 'central_wavelength': 658.0, 'bandwidth': 138.0, 'zero_point': 9740000000.0}, 'I': {'sun': -27.47, 'sky': 20.0, 'space': 21.2, 'central_wavelength': 806.0, 'bandwidth': 149.0, 'zero_point': 7110000000.0}, 'J': {'sun': -27.91, 'sky': 16.0, 'space': 21.5, 'central_wavelength': 1235.0, 'bandwidth': 162.0, 'zero_point': 3150000000.0}, 'H': {'sun': -28.25, 'sky': 14.0, 'space': 20.5, 'central_wavelength': 1646.0, 'bandwidth': 251.0, 'zero_point': 2350000000.0}, 'K': {'sun': -28.29, 'sky': 13.0, 'space': 19.5, 'central_wavelength': 2159.0, 'bandwidth': 262.0, 'zero_point
# ...

# %%
print(FILTER_DATA['V'])
# Out:
# {'sun': -26.78, 'sky': 21.9, 'space': 23, 'central_wavelength': 551.0, 'bandwidth': 88.0, 'zero_point': 8790000000.0}

# %%
import constellation
# Out:
# Traceback (most recent call last):
#
#   File /opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[3], line 1
#     import constellation
#
#   File ~/Desktop/vibevolts/constellation.py:91
#     SIM_DATA['SATELLITES']['DETECTOR'] = NP.VSTACK([SIM_DATA['SATELLITES']['DETECTOR'],   NP.ZEROS((N,DETECTOR_ARRAY_SIZE)])
#                                                                                                                           ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('
