# %%
# %run all_demos.py
# Out:
# --- LOADING PROPAGATION.PY ---
# --- Running All Demos ---
#
# --- Executing demo1 ---
# Initializing standard simulation with 23 satellites.
# Propagating satellites to start time: 2025-07-27T22:27:00+00:00 to set initial state.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/vibevolts/all_demos.py:62
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/Desktop/vibevolts/all_demos.py:49, in run_all_demos()
#      47 for func in demo_functions:
#      48     print(f"\n\033--- Executing {func.__name__} ---\033")
# ---> 49     result = func()
#      50     if isinstance(result, go.Figure):
#      51         result.show()
#
# File ~/Desktop/vibevolts/demo1.py:19, in demo1()
#       9 """
#      10 Runs a full demonstration of the simulation tools.
#      11
#    (...)
# ...

# %%
from math import pi

# %%
print(4 * pi / ( pi * (10/50)**2 ))
# Out:
# 99.99999999999999

# %%
from random import randint

# %%
randint(0,1)
# Out:
# 0
