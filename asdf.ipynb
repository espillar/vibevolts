# %%
# %run radiometry.py
# Out:
# --- Physical Constants ---
# Astronomical Unit (AU): 1.496e+11 m
# Radius of the Sun (R_sun): 6.957e+08 m
#
# --- Radiometric Filter Data ---
# {'B': {'bandwidth': 94.0,
#        'central_wavelength': 445.0,
#        'sky': 22.7,
#        'sun': -26.13,
#        'zero_point': 13600000000.0},
#  'F1000W': {'bandwidth': 1800.0,
#             'central_wavelength': 10000.0,
#             'sky': 23.6,
#             'sun': None,
#             'zero_point': 9860000000.0},
#  'F1500W': {'bandwidth': 2940.0,
#             'central_wavelength': 15000.0,
#             'sky': 21.9,
#             'sun': None,
#             'zero_point': 10800000000.0},
#  'F2550W': {'bandwidth': 4050.0,
#             'central_wavelength': 25500.0,
#             'sky': 19.4,
#             'sun': None,
#             'zero_point': 8700000000.0},
#  'F560W': {'bandwidth': 1000.0,
#            'central_wavelength': 5600.0,
#            'sky': 24.4,
#            'sun': None,
#            'zero_point': 9780000000.0},
# ...
