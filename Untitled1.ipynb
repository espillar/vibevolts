# %%
# %run all_demos.py
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/Desktop/vibevolts/all_demos.py:17
#      15 from demo_sky_scan import demo_sky_scan
#      16 from demo_pointing_vectors import demo_pointing_vectors
# ---> 17 from demo_pointing_sequence import demo_pointing_sequence
#      18 from demo_constellation import demo_constellation
#      19 from demo_show_geo_search import demo_show_geo_search
#
# File ~/Desktop/vibevolts/demo_pointing_sequence.py:9
#       7 from propagation import add_satellites_from_tle
#       8 from constants import POINTING_COUNT_IDX, POINTING_PLACE_IDX
# ----> 9 from pointing import generate_pointing_sphere, update_satellite_pointing, pointing_place_update
#      10 from plotting_vectors import plot_pointing_vectors
#      12 def demo_pointing_sequence() -> go.Figure:
#
# ...
