# %%
# %run simulationTemplate.py
# Out:
# Generating pointing sphere with 656 points...
# Simulation initialized with 1 satellites.
#
# --- Step 0: 2025-01-01T12:00:00+00:00 ---
# Satellite 0 Position: [42164140.        0.        0.]
# Scan performed for group 0
#
# --- Step 1: 2025-01-01T12:10:00+00:00 ---
# Satellite 0 Position: [42123788.98110612  1844208.18099327        0.        ]
# Scan performed for group 0
#
# --- Step 2: 2025-01-01T12:20:00+00:00 ---
# Satellite 0 Position: [42002813.1561539   3684886.55304673        0.        ]
# Scan performed for group 0
#
# --- Step 3: 2025-01-01T12:30:00+00:00 ---
# Satellite 0 Position: [41801444.07251029  5518512.06326435        0.        ]
# Scan performed for group 0
#
# --- Step 4: 2025-01-01T12:40:00+00:00 ---
# Satellite 0 Position: [41520067.14999881  7341575.1579065         0.        ]
# Scan performed for group 0
