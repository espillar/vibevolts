# %%
# %run all_demos.py
# Out:
# --- Running All Demos ---
#
# --- Executing demo2 ---
# Initializing standard simulation with 23 satellites.
# Propagating satellites to start time: 2025-07-27T22:27:00+00:00 to set initial state.
#
# --- Generating 3D plot for Demo 2 ---
# appending a single item
#
# --- Executing demo3 ---
#
# --- Starting Demo 3 ---
# Initializing structures for 1 LEO satellite.
#
# --- Generating 3D plot for Demo 3 ---
# appending a single item
#
# --- Executing demo_fixedpoints ---
#
# --- Starting Demo Fixedpoints ---
# Plotting 100 fixed points.
# appending a single item
#
# --- Executing demo_exclusion_table ---
#
# --- Starting Demo: Exclusion Table Visualization ---
# Initializing standard simulation with 23 satellites.
# Propagating satellites to start time: 2025-08-01T12:00:00+00:00 to set initial state.
# Calculating celestial body positions...
# Generating exclusion table (this may take a moment)...
# Exclusion table generated.
# Displaying results as a heatmap...
# ...
