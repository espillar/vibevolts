# %% [markdown]
# # VibeVolts Demo Suite
#
# This notebook demonstrates VibeVolts simulation capabilities grouped into thematic suites.
# Running demos in groups avoids browser WebGL context limit errors (~16 max per page).

# %%
import all_demos
all_demos.list_demo_groups()

# %% [markdown]
# ## 1. Orbits & Constellations

# %%
all_demos.run_all_demos(group='orbits')

# %% [markdown]
# ## 2. Pointing & Scanning

# %%
all_demos.run_all_demos(group='pointing')

# %% [markdown]
# ## 3. Radiometry & Target Exclusion

# %%
all_demos.run_all_demos(group='radiometry')

# %% [markdown]
# ## 4. Save All Demos to HTML Report

# %%
# Export all 18+ demos into a standalone HTML file
all_demos.run_all_demos(group='all', save_html=True)
